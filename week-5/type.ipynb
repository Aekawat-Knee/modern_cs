# %%
Fullname = ("Aekawat Ruypirom")
studentID = 684245020
Gpax = 3.20
Age = 19


if(type(Fullname) == str):
    print(" is Str", Fullname)
else:
    print("is not str", Fullname)
if(type(studentID)== complex):
    print(" is complex", studentID)
else:
    print(" is not complex", studentID)
if(type(Gpax)== float):
    print(" is float", Gpax)
else:
    print(" is not float", Gpax)
if(type(Age)== int):
    print(" is int", Age)
else:
    print(" is not int", Age)
# Out:
#  is Str Aekawat Ruypirom
#  is not complex 684245020
#  is float 3.2
#  is int 19
